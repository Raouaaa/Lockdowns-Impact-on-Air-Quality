# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
AirQuality2021=pd.read_csv('https://aqicn.org/data-platform/covid19/report/13220-61539cf0/2020',skiprows=4)

# %%
AirQuality2020Q1=pd.read_csv('https://aqicn.org/data-platform/covid19/report/13220-61539cf0/2020Q1',skiprows=4)

# %%
AirQuality2020Q2=pd.read_csv('https://aqicn.org/data-platform/covid19/report/13220-61539cf0/2020Q2',skiprows=4)

# %%
AirQuality2020Q3=pd.read_csv('https://aqicn.org/data-platform/covid19/report/13220-61539cf0/2020Q3',skiprows=4)

# %%
AirQuality2020Q4=pd.read_csv('https://aqicn.org/data-platform/covid19/report/13220-61539cf0/2020Q4',skiprows=4)

# %%
  AirQuality2019Q1=pd.read_csv('https://aqicn.org/data-platform/covid19/report/13220-61539cf0/2019Q1',skiprows=4)

# %%
AirQuality2019Q2=pd.read_csv('https://aqicn.org/data-platform/covid19/report/13220-61539cf0/2019Q2',skiprows=4)

# %%
AirQuality2019Q3=pd.read_csv('https://aqicn.org/data-platform/covid19/report/13220-61539cf0/2019Q3',skiprows=4)

# %%
AirQuality2019Q4=pd.read_csv('https://aqicn.org/data-platform/covid19/report/13220-61539cf0/2019Q4',skiprows=4)

# %%
#lockdown=pd.read_csv('https://www.kaggle.com/sudalairajkumar/novel-corona-virus-2019-dataset',skiprows=6)

# %%
AirQuality2019_2020_2021=pd.concat([AirQuality2019Q1,AirQuality2019Q2,AirQuality2019Q3,AirQuality2019Q4,AirQuality2020Q1,AirQuality2020Q2,AirQuality2020Q3,AirQuality2020Q4,AirQuality2021],axis=0)

# %% [markdown]
# **pm25 in 2020**

# %%
AirQuality2020_2021=pd.concat([AirQuality2020Q1,AirQuality2020Q2,AirQuality2020Q3,AirQuality2020Q4],axis=0)
Airquality2020species=AirQuality2020.groupby('Specie')
Airquality2020_2021species_pm25=Airquality2020_2021species.get_group('pm25')
Airquality2020_2021species_pm25=Airquality2020_2021species_pm25.drop(columns=['count','min','median','variance'],axis=1)
Airquality2020_2021species_pm25.reset_index(drop=True,inplace=True)
Airquality2020_2021species_pm25=Airquality2020_2021species_pm25.sort_values(by='max',ascending=False)
Airquality2020_2021species_pm25.reset_index(drop=True,inplace=True)
Airquality2020_2021species_pm25Topranked=Airquality2020_2021species_pm25.head(10)
Airquality2020_2021species_pm25Topranked
# Out:
#          Date Country          City Specie    max
# 0  2020-02-29      FR      Grenoble   pm25  999.0
# 1  2021-07-09      CN  Shijiazhuang   pm25  999.0
# 2  2020-04-18      CN        Harbin   pm25  999.0
# 3  2020-12-28      TR         Konya   pm25  999.0
# 4  2021-07-08      CN  Shijiazhuang   pm25  999.0
# 5  2021-06-03      MX   Mexico City   pm25  999.0
# 6  2019-12-31      AU      Canberra   pm25  999.0
# 7  2021-08-14      AU        Darwin   pm25  999.0
# 8  2020-01-01      AU      Canberra   pm25  999.0
# 9  2021-03-27      MX        Puebla   pm25  999.0

# %% [markdown]
# **Top ranked coutries and cities in pm25**

# %%
plt.figure(figsize = (15,8))
plt.style.use('fivethirtyeight')
sns.barplot(x='Date',y='max',hue='Country',data=Airquality2020_2021species_pm25Topranked)
plt.title('Top ten Ranked countries in pm25 air pollution in 2020_2021')
plt.show()

# %%
plt.figure(figsize = (15,8))
plt.style.use('fivethirtyeight')
sns.barplot(x='Date',y='max',hue='City',data=Airquality2020_2021species_pm25Topranked)
plt.title('Top ten Ranked cities in pm25 air pollution in 2020_2021')
plt.show()

# %% [markdown]
# in all top ten countries and cities Pm25 was 999
