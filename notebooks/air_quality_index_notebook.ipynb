# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
D2021 = pd.read_csv('D:/Data Camp/Data/airquality2020.csv', skiprows = 4)
D2021.head()
# Out:
#          Date Country       City      Specie  count  min  max  median  \
# 0  2021-01-20      TH  Chon Buri  wind-speed     96  0.5  5.4     3.0
# 1  2021-08-16      TH  Chon Buri  wind-speed     93  0.2  5.1     2.5
# 2  2021-08-17      TH  Chon Buri  wind-speed     96  0.2  4.8     1.8
# 3  2021-09-04      TH  Chon Buri  wind-speed     89  0.5  6.6     2.3
# 4  2021-01-25      TH  Chon Buri  wind-speed     96  1.0  5.1     2.0
#
#    variance
# 0     10.85
# 1     15.82
# 2     11.36
# 3     36.23
# 4     11.15

# %%
A19= pd.read_csv('D:/Data Camp/Data/2019Q1.csv', skiprows = 4)

# %%
A19.head()
# Out:
#          Date Country       City Specie  count    min    max  median  variance
# 0  2019-01-16      AE  Abu Dhabi   pm10     24   86.0   99.0    97.0    179.40
# 1  2019-01-22      AE  Abu Dhabi   pm10     24   51.0   57.0    55.0     23.75
# 2  2019-01-26      AE  Abu Dhabi   pm10     24  136.0  173.0   160.0    941.96
# 3  2019-01-07      AE  Abu Dhabi   pm10     24   60.0   91.0    72.0   1006.88
# 4  2019-01-10      AE  Abu Dhabi   pm10     24   82.0   93.0    87.0     57.97

# %%
B19= pd.read_csv('D:/Data Camp/Data/2019Q2.csv', skiprows = 4)

# %%
C19= pd.read_csv('D:/Data Camp/Data/2019Q3.csv', skiprows = 4)

# %%
D19= pd.read_csv('D:/Data Camp/Data/2019Q4.csv', skiprows = 4)

# %%
A20= pd.read_csv('D:/Data Camp/Data/2020Q1.csv', skiprows = 4)

# %%
B20= pd.read_csv('D:/Data Camp/Data/2020Q2.csv', skiprows = 4)

# %%
C20= pd.read_csv('D:/Data Camp/Data/2020Q3.csv', skiprows = 4)

# %%
D20= pd.read_csv('D:/Data Camp/Data/2020Q4.csv', skiprows = 4)

# %%
merged = pd.concat([D2021, A19,B19,C19,D19,A20,B20,C20,D20])

# %%
merged.tail()
# Out:
#               Date Country    City Specie  count  min   max  median  variance
# 586932  2020-12-31      PL  Kraków     o3    144  1.7   8.1     4.6     28.32
# 586933  2021-01-03      PL  Kraków     o3    144  0.5   7.1     2.1     30.05
# 586934  2020-10-12      PL  Kraków     o3    144  4.6  16.0    12.7     81.38
# 586935  2020-10-16      PL  Kraków     o3    144  1.2   5.9     3.5     18.86
# 586936  2020-10-30      PL  Kraków     o3    144  3.6  21.9     9.9    232.88

# %%
D2021.tail()
# Out:
#                Date Country             City      Specie  count  min  max  \
# 1716138  2021-05-27      UA  Ivano-Frankivsk  wind-speed     60  0.5  2.5
# 1716139  2021-05-28      UA  Ivano-Frankivsk  wind-speed     70  1.0  4.1
# 1716140  2021-07-19      UA  Ivano-Frankivsk  wind-speed     56  0.2  4.5
# 1716141  2020-12-30      UA  Ivano-Frankivsk  wind-speed     28  0.2  2.0
# 1716142  2021-04-08      UA  Ivano-Frankivsk  wind-speed     64  1.5  7.7
#
#          median  variance
# 1716138     1.0      3.80
# 1716139     3.0      6.64
# 1716140     1.5     12.46
# 1716141     0.5      3.66
# 1716142     5.1     29.50

# %%
D20.tail()
# Out:
#               Date Country    City Specie  count  min   max  median  variance
# 586932  2020-12-31      PL  Kraków     o3    144  1.7   8.1     4.6     28.32
# 586933  2021-01-03      PL  Kraków     o3    144  0.5   7.1     2.1     30.05
# 586934  2020-10-12      PL  Kraków     o3    144  4.6  16.0    12.7     81.38
# 586935  2020-10-16      PL  Kraków     o3    144  1.2   5.9     3.5     18.86
# 586936  2020-10-30      PL  Kraków     o3    144  3.6  21.9     9.9    232.88

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6218170 entries, 0 to 586936
# Data columns (total 9 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   Date      object
#  1   Country   object
#  2   City      object
#  3   Specie    object
#  4   count     int64
#  5   min       float64
#  6   max       float64
#  7   median    float64
#  8   variance  float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 474.4+ MB

# %%
merged.isna().sum()
# Out:
# Date        0
# Country     0
# City        0
# Specie      0
# count       0
# min         0
# max         0
# median      0
# variance    0
# dtype: int64

# %%
merged['Specie'].unique()
# Out:
# array(['wind-speed', 'dew', 'temperature', 'pm10', 'humidity', 'o3',
#        'so2', 'pm25', 'no2', 'co', 'wind-gust', 'pressure', 'pm1',
#        'precipitation', 'wd', 'aqi', 'neph', 'uvi', 'mepaqi', 'pol',
#        'wind speed', 'wind gust'], dtype=object)

# %%
merged.head()
# Out:
#               Date Country         City Specie  count     min     max  median  \
# 431827  2019-07-22      CN  Qinhuangdao    pol      2 -3065.6 -3065.6 -3065.6
# 326238  2019-11-09      CN       Anyang    pol      2 -3065.6 -3065.6 -3065.6
# 326240  2019-10-13      CN       Anyang    pol      3 -3065.6 -3065.6 -3065.6
# 431771  2019-09-30      CN  Qinhuangdao    pol      6 -3065.6   524.8 -3065.6
# 326242  2019-10-24      CN       Anyang    pol      6 -3065.6  -549.6 -3065.6
#
#           variance
# 431827         0.0
# 326238         0.0
# 326240         0.0
# 431771  19376900.0
# 326242  18990800.0

# %%
merged['Date'] =  pd.to_datetime(merged['Date'])

# %%
o3 = D2021.loc[D2021['Specie'] == 'o3']

# %%
o3.head()
# Out:
#             Date Country       City Specie  count  min   max  median  variance
# 1441  2021-02-28      TH  Chon Buri     o3     80  0.4  22.1     7.1    268.33
# 1442  2021-04-23      TH  Chon Buri     o3     82  0.4  17.8     6.4    145.72
# 1443  2021-05-12      TH  Chon Buri     o3     82  1.2  16.6     6.7    126.49
# 1444  2021-06-03      TH  Chon Buri     o3     91  1.6  17.8     6.7    130.04
# 1445  2021-07-24      TH  Chon Buri     o3     89  2.4   8.3     5.2     19.68

# %%
o3_sorted = o3.sort_values(["max"], ascending=False)

# %%
o3_sorted.head()
# Out:
#               Date Country           City Specie  count   min    max  median  \
# 687665  2021-09-23      BR        Vitória     o3     72   1.9  811.0    24.0
# 687670  2021-09-22      BR        Vitória     o3     52  21.9  546.6    26.0
# 620700  2021-05-31      IN         Mumbai     o3    209   0.1  500.0     2.7
# 288485  2021-02-24      US  Staten Island     o3     26   0.8  500.0    24.1
# 784327  2021-07-07      CN   Shijiazhuang     o3    617   8.2  500.0    51.9
#
#         variance
# 687665  218273.0
# 687670  172034.0
# 620700   15966.8
# 288485  171209.0
# 784327  354676.0

# %%
o3_top_ten_cities = o3_sorted[0: 21]

# %%
o3_top_ten_cities.head(10)
# Out:
#                Date Country           City Specie  count   min    max  median  \
# 687665   2021-09-23      BR        Vitória     o3     72   1.9  811.0    24.0
# 687670   2021-09-22      BR        Vitória     o3     52  21.9  546.6    26.0
# 620700   2021-05-31      IN         Mumbai     o3    209   0.1  500.0     2.7
# 288485   2021-02-24      US  Staten Island     o3     26   0.8  500.0    24.1
# 784327   2021-07-07      CN   Shijiazhuang     o3    617   8.2  500.0    51.9
# 782106   2021-07-09      CN    Qinhuangdao     o3    192   0.1  500.0   500.0
# 1434091  2021-10-03      TR         Ankara     o3     44   0.5  500.0     2.4
# 620787   2021-06-14      IN         Mumbai     o3    229   0.1  500.0     4.7
# 288339   2021-01-29      US  Staten Island     o3     26  24.1  500.0    27.2
# 288247   2021-02-23      US  Staten Island     o3     23   0.8  500.0    18.4
#
#          variance
# 687665   218273.0
# 687670   172034.0
# 620700    15966.8
# 288485   171209.0
# ...

# %%
plt.style.use('bmh')
plt.figure(figsize=(14,8))
sns.barplot(o3_top_ten_cities['City'], o3_top_ten_cities['max'], palette='magma')
plt.xticks(rotation=45)
plt.title('Distribution of country listed in data');
plt.show()
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
o3_top_ten_countries = o3_sorted[0: 70]

# %%
plt.style.use('bmh')
plt.figure(figsize=(14,8))
sns.barplot(o3_top_ten_countries['Country'], o3_top_ten_countries['max'], palette='magma')
plt.xticks(rotation=45)
plt.title('Distribution of country listed in data');
plt.show()
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
